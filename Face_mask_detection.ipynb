# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanveerwali/facemask-detection-yolov8/blob/main/Face_mask_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.8 MB/s eta 0:00:00
# ...

# %%
# !yolo detect train \
  data=/content/drive/MyDrive/facemask_detection/data.yaml \
  model=yolov8n.pt \
  epochs=10 \
  imgsz=640 \
  project=/content/drive/MyDrive/facemask_detection \
  name=training
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.12 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !yolo detect predict \
  model=/content/drive/MyDrive/facemask_detection/training/weights/best.pt \
  source=/content/drive/MyDrive/facemask_detection/images \
  save=True \
  project=/content/drive/MyDrive/facemask_detection \
  name=outputs
# Out:
# Ultralytics 8.4.12 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/350 /content/drive/MyDrive/facemask_detection/images/0-with-mask.jpg: 448x640 1 Mask, 162.9ms
# image 2/350 /content/drive/MyDrive/facemask_detection/images/0.jpg: 640x448 1 no_mask, 157.1ms
# image 3/350 /content/drive/MyDrive/facemask_detection/images/0181ce93-59-with-mask.jpg: 640x480 1 Mask, 173.7ms
# image 4/350 /content/drive/MyDrive/facemask_detection/images/02f9b18b-13.jpg: 640x480 1 no_mask, 250.1ms
# image 5/350 /content/drive/MyDrive/facemask_detection/images/03b87a95-52-with-mask.jpg: 640x480 1 Mask, 236.1ms
# image 6/350 /content/drive/MyDrive/facemask_detection/images/04e25fdc-99-with-mask.jpg: 640x512 1 Mask, 256.2ms
# image 7/350 /content/drive/MyDrive/facemask_detection/images/0582672b-10-with-mask.jpg: 640x448 1 Mask, 210.7ms
# ...
